# %%
import dill
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.types import NVARCHAR

def csv_it(dataframe, filebase):
    dataframe.to_csv('./csv/'+filebase+'.csv', sep=',', index=False, encoding='utf-8')
    return

def pkl_it(dataframe, filebase):
    with open('./pkl/'+filebase+'.pkl', 'wb') as fh:
        dill.dump(dataframe, fh)

    return

def sql_it(dataframe, filebase, dbname='zika'): #check!
    postgres_str = 'postgresql://abhijit:{}@127.0.0.1:6742/{}'.format(POSTGRES_PWD, dbname)
    engine = create_engine(postgres_str)
    dataframe.to_sql(filebase, engine, if_exists='replace', dtype={col_name: NVARCHAR for col_name in filebase})
    return

def save_it(dataframe, filebase, dbname='zika'):
    csv_it(dataframe, filebase)
    pkl_it(dataframe, filebase)
    sql_it(dataframe, 'sql_' + filebase, dbname=dbname)
    return

# %%
import numpy as np
import os
import pandas as pd
import dill
from datetime import timedelta
from dateutil.parser import parser
import sys
import os
f = 'csv_pkl_sql.py'
for path, dirs, files in os.walk(os.path.expanduser('~/')):    
    if f in files:
        dir_ = path
        break
os.chdir(dir_)
try:
    from csv_pkl_sql import save_it, csv_it, pkl_it
except: 
    print("Change to the project directory")
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import numpy as np
from csv_pkl_sql import csv_it, sql_it
#import cPickle as pickle

from osgeo import gdal

# %%
# Import the latitude and longitude data
lat_long_data = pd.read_csv('./csv/01_latitude_longitude_google.csv')


# # Import the geoTIF map
# ds = ('./gpw_population_density/gpw-v4-population-density_2020.tif')

# %%
# print(ds)

# %%
# import pickle
# # rows = ds.RasterYSize
# # cols = ds.RasterXSize

# # transform = ds.GetGeoTransform()
# # xOrigin = transform[0]
# # yOrigin = transform[3]
# # pixelWidth = transform[1]
# # pixelHeight = transform[5]


# # band = ds.GetRasterBand(1)


# # def get_population_density(latitude, longitude, 
# #                            xOrigin=xOrigin, yOrigin=yOrigin,
# #                            pixelWidth=pixelWidth, pixelHeight=pixelHeight,
# #                            band=band):

#     # # Single point, x=longitude, y=latitude

# #     x = longitude
# #     y = latitude

#     # This reads three pixels in x- and y- direction
# #     try:
# #         #  read 3 x 3 region
# #         size = 100

# #         dist_matrix = np.meshgrid(np.arange(-size, size+1), 
# #                                   np.arange(-size, size+1))
# #         dist_matrix = np.sqrt((dist_matrix[0]**2 + dist_matrix[1]**2))
# #         sort_order = dist_matrix.ravel().argsort()

# #         xOffset = int((x - xOrigin) / pixelWidth) - size
# #         yOffset = int((y - yOrigin) / pixelHeight) - size

# #         data = band.ReadAsArray(xOffset, yOffset, 2*size+1, 2*size+1)
# #         data_sort = data.ravel()[sort_order]

# #         density = data_sort[data_sort>0][:9].mean()
# #     except:
# #         density = np.NaN

# #     return density


# lat_long_data['density_per_km'] = lat_long_data.apply(lambda x: get_population_density(x.latitude, x.longitude), axis=1)

# # #lat_long_data[['location','density_per_km']].to_csv('../csv/06_population_density.csv')
# # csv_it(lat_long_data[['location','density_per_km']], '06_population_density')

# # with open('./pkl/06_population_density.pkl', 'wb') as fh:
# #     pickle.dump(lat_long_data[['location','density_per_km']], fh)

# # #sql_it(lat_long_data[['location','density_per_km']], '06_population_density')

# %%
lat_long_data
# Out:
#                                        location location_type        country  \
# 0                        Argentina-Buenos_Aires      province      Argentina
# 1                                Argentina-CABA      province      Argentina
# 2                             Argentina-Cordoba      province      Argentina
# 3                          Argentina-Entre_Rios      province      Argentina
# 4                            Argentina-Santa_Fe      province      Argentina
# 5                               Argentina-Chaco      province      Argentina
# 6                          Argentina-Corrientes      province      Argentina
# 7                             Argentina-Formosa      province      Argentina
# 8                            Argentina-Misiones      province      Argentina
# 9                           Argentina-Catamarca      province      Argentina
# 10                              Argentina-Jujuy      province      Argentina
# 11                              Argentina-Salta      province      Argentina
# 12                     Argentina-Sgo_Del_Estero      province      Argentina
# 13                            Argentina-Tucuman      province      Argentina
# 14                           Argentina-La_Rioja      province      Argentina
# 15                           Argentina-San_Luis      province      Argentina
# 16                            Argentina-Mendoza      province      Argentina
# 17                           Argentina-San_Juan      province      Argentina
# 18                             Argentina-Chubut      province      Argentina
# 19                           Argentina-La_Pampa      province      Argentina
# 20                          Argentina-Rio_Negro      province      Argentina
# 21                         Argentina-Santa_Cruz      province      Argentina
# 22                            Argentina-Neuquen      province      Argentina
# 23                   Argentina-Tierra_del_Fuego      province      Argentina
# 24                               Brazil-Alagoas      province         Brazil
# 25                                 Brazil-Bahia      province         Brazil
# 26                                 Brazil-Ceara      province         Brazil
# 27                              Brazil-Maranhao      province         Brazil
# 28                               Brazil-Paraiba      province         Brazil
# 29                            Brazil-Pernambuco      province         Brazil
# ...                                         ...           ...            ...
# 1684        United_States-Florida-Martin_County        county  United States
# 1685    United_States-Florida-Miami_Dade_County        county  United States
# 1686        United_States-Florida-Monroe_County        county  United States
# 1687        United_States-Florida-Nassau_County        county  United States
# 1688      United_States-Florida-Okaloosa_County        county  United States
# 1689    United_States-Florida-Okeechobee_County        county  United States
# 1690        United_States-Florida-Orange_County        county  United States
# 1691       United_States-Florida-Osceola_County        county  United States
# 1692     United_States-Florida-PalmBeach_County        county  United States
# 1693         United_States-Florida-Pasco_County        county  United States
# 1694      United_States-Florida-Pinellas_County        county  United States
# 1695          United_States-Florida-Polk_County        county  United States
# 1696        United_States-Florida-Putnam_County        county  United States
# 1697     United_States-Florida-SantaRosa_County        county  United States
# 1698      United_States-Florida-Sarasota_County        county  United States
# 1699      United_States-Florida-Seminole_County        county  United States
# 1700       United_States-Florida-StJohns_County        county  United States
# 1701       United_States-Florida-StLucie_County        county  United States
# 1702        United_States-Florida-Sumter_County        county  United States
# 1703      United_States-Florida-Suwannee_County        county  United States
# 1704        United_States-Florida-Taylor_County        county  United States
# 1705         United_States-Florida-Union_County        county  United States
# 1706       United_States-Florida-Volusia_County        county  United States
# 1707       United_States-Florida-Wakulla_County        county  United States
# 1708        United_States-Florida-Walton_County        county  United States
# 1709    United_States-Florida-Washington_County        county  United States
# 1710               United_States_Virgin_Islands      province  United States
# 1711  United_States_Virgin_Islands-Saint_Thomas        county  United States
# 1712   United_States_Virgin_Islands-Saint_Croix        county  United States
# 1713    United_States_Virgin_Islands-Saint_John        county  United States
#
#                     province        county               city   latitude  \
# 0               Buenos Aires           NaN                NaN -34.603684
# 1     Ciudad de Buenos Aires           NaN                NaN -34.603684
# 2                    Cordoba           NaN                NaN -31.420083
# 3                 Entre Rios           NaN                NaN -31.774665
# 4                   Santa Fe           NaN                NaN -31.610658
# 5                      Chaco           NaN                NaN -27.425717
# 6                 Corrientes           NaN                NaN -27.469213
# 7                    Formosa           NaN                NaN -26.185777
# 8                   Misiones           NaN                NaN -27.426925
# 9                  Catamarca           NaN                NaN -28.469581
# 10                     Jujuy           NaN                NaN -24.184340
# 11                     Salta           NaN                NaN -24.782127
# 12       Santiago Del Estero           NaN                NaN -27.783357
# 13                   Tucuman           NaN                NaN -26.808285
# 14                  La Rioja           NaN                NaN -29.413454
# 15                  San Luis           NaN                NaN -33.301727
# 16                   Mendoza           NaN                NaN -32.889459
# 17                  San Juan           NaN                NaN -31.535107
# 18                    Chubut           NaN                NaN -43.293425
# 19                  La Pampa           NaN                NaN -36.614757
# 20                 Rio Negro           NaN                NaN -40.826143
# 21                Santa Cruz           NaN                NaN -51.635282
# 22                   Neuquen           NaN                NaN -38.951678
# 23          Tierra del Fuego           NaN                NaN -54.805400
# 24                   Alagoas           NaN                NaN  -9.571306
# 25                     Bahia           NaN                NaN -12.579738
# 26                     Ceara           NaN                NaN  -5.498398
# 27                  Maranhao           NaN                NaN  -4.960950
# 28                   Paraiba           NaN                NaN  -7.239961
# 29                Pernambuco           NaN                NaN  -8.813717
# ...                      ...           ...                ...        ...
# 1684                 Florida        Martin      Martin County  36.343397
# 1685                 Florida    Miami Dade  Miami Dade County  25.551603
# 1686                 Florida        Monroe      Monroe County  32.509311
# 1687                 Florida        Nassau      Nassau County  25.047984
# 1688                 Florida      Okaloosa    Okaloosa County  30.577340
# 1689                 Florida    Okeechobee  Okeechobee County  27.243935
# 1690                 Florida        Orange      Orange County  33.787914
# 1691                 Florida       Osceola     Osceola County  45.320520
# 1692                 Florida     PalmBeach   PalmBeach County  26.705621
# 1693                 Florida         Pasco       Pasco County  46.230505
# 1694                 Florida      Pinellas    Pinellas County  27.876394
# 1695                 Florida          Polk        Polk County  27.861735
# 1696                 Florida        Putnam      Putnam County  41.904601
# 1697                 Florida     SantaRosa   SantaRosa County  38.440429
# 1698                 Florida      Sarasota    Sarasota County  27.336435
# 1699                 Florida      Seminole    Seminole County  27.839747
# 1700                 Florida       StJohns     StJohns County  18.336811
# 1701                 Florida       StLucie     StLucie County  27.322556
# 1702                 Florida        Sumter      Sumter County  33.920435
# 1703                 Florida      Suwannee    Suwannee County  30.248510
# 1704                 Florida        Taylor      Taylor County  42.240872
# 1705                 Florida         Union       Union County  45.233412
# 1706                 Florida       Volusia     Volusia County  29.027984
# 1707                 Florida       Wakulla     Wakulla County  30.130169
# 1708                 Florida        Walton      Walton County  38.875619
# 1709                 Florida    Washington  Washington County  47.751074
# 1710          Virgin Islands           NaN                NaN  18.335765
# 1711          Virgin Islands  Saint Thomas                NaN  18.338096
# 1712          Virgin Islands   Saint Croix                NaN  17.724597
# 1713          Virgin Islands    Saint John                NaN  18.356343
#
#        longitude
# 0     -58.381559
# 1     -58.381559
# 2     -64.188776
# 3     -60.495646
# 4     -60.697294
# 5     -59.024378
# 6     -58.830635
# 7     -58.175567
# 8     -55.946708
# 9     -65.779544
# 10    -65.302177
# 11    -65.423198
# 12    -64.264167
# 13    -65.217590
# 14    -66.856458
# 15    -66.337752
# 16    -68.845839
# 17    -68.538594
# 18    -65.111482
# 19    -64.283921
# 20    -63.026634
# 21    -69.247435
# 22    -68.059189
# 23    -68.324206
# 24    -36.781951
# 25    -41.700727
# 26    -39.320624
# 27    -45.274416
# 28    -36.781951
# 29    -36.954107
# ...          ...
# 1684  -88.850338
# 1685  -80.632692
# 1686  -92.119301
# 1687  -77.355413
# 1688  -86.661108
# 1689  -80.829783
# 1690 -117.853101
# 1691  -92.704930
# 1692  -80.036430
# 1693 -119.092232
# 1694  -82.777858
# 1695  -81.691156
# 1696  -71.868992
# 1697 -122.714055
# 1698  -82.530653
# 1699  -82.791213
# 1700  -64.728095
# 1701  -80.543845
# 1702  -80.341469
# 1703  -82.993161
# 1704  -83.269651
# 1705 -118.041063
# 1706  -81.075466
# 1707  -84.354205
# 1708  -84.610221
# 1709 -120.740139
# 1710  -64.896335
# 1711  -64.894095
# 1712  -64.834799
# 1713  -64.700136
#
# [1714 rows x 8 columns]

# %%
import pandas as pd
import numpy as np
import dill
from datetime import timedelta

# %%
import matplotlib.pyplot as plt
import seaborn as sns
with open('./pkl/00_cleaned_city_names.pkl', 'rb') as fh:
    location_key = dill.load(fh)
location_key.head(1)
# Out:
#                  location location_type    country      province county  city
# 0  Argentina-Buenos_Aires      province  Argentina  Buenos Aires   None  None

# %%
with open('./pkl/01_latitude_longitude_google.pkl', 'rb') as fh:
    lat_long = dill.load(fh)
lat_long.head(1)
lat_long = lat_long[['location','latitude','longitude']]
location_key.shape, lat_long.shape
location = pd.merge(location_key, lat_long, on='location', how='inner')
location.head(1)
# Out:
#                  location location_type    country      province county  city  \
# 0  Argentina-Buenos_Aires      province  Argentina  Buenos Aires   None  None
#
#     latitude  longitude
# 0 -34.603684 -58.381559

# %%
location.shape
# Out:
# (1724, 8)

# %%
save_it(location[['location','country']], '11_feature_engineering_location')

# %%
with open('./pkl/02_airport_information_fallingrain.pkl', 'rb') as fh:
    airport = dill.load(fh)
airport.head(1)
# Out:
#    Airlines          city  FAA IATA  ICAO    kind  latitude  longitude  \
# 70        4  BAHIA BLANCA  NaN  BHI  SAZB  Medium   -38.725    -62.169
#
#     max_runway               name    country state
# 70      8579.0  COMANDANTE ESPORA  Argentina   NaN

# %%
airport = airport[['city', 'FAA', 'IATA', 'ICAO', 'kind', 'latitude',
       'longitude', 'max_runway', 'name', 'country', 'state']]
airport.head(1)
# Out:
#             city  FAA IATA  ICAO    kind  latitude  longitude  max_runway  \
# 70  BAHIA BLANCA  NaN  BHI  SAZB  Medium   -38.725    -62.169      8579.0
#
#                  name    country state
# 70  COMANDANTE ESPORA  Argentina   NaN

# %%
with open('./pkl/04_merged_latitude_longitude_airport_checkpoint.pkl', 'rb') as fh:
    airport2 = dill.load(fh)
airport2.head(1)
airport2 = airport2[['location', 'latitude', 'longitude', 'airport_index', 'country', 'name', 'FAA', 'IATA',
       'ICAO']]
airport.shape, airport2.shape
# Out:
# ((2247, 11), (1714, 9))

# %%
airport.kind.unique()
save_it(airport, '11_feature_engineering_airport')

# %%
# Closest medium or large airport
airport_coords = airport[['latitude', 'longitude']].values[np.newaxis, :]
places_coords = np.rollaxis(lat_long[['latitude','longitude']].values[np.newaxis, :], 0, -1)
dist_coords = ((places_coords - airport_coords)**2).sum(axis=-1)
min_dist = dist_coords.min(axis=1)

airport_distance = lat_long[['location']].copy()
airport_distance['airport_dist_any'] = min_dist

# Closest large airport
airport_coords = airport.loc[airport.kind=='Large', 
                             ['latitude', 'longitude']].values[np.newaxis, :]
places_coords = np.rollaxis(lat_long[['latitude','longitude']].values[np.newaxis, :], 0, -1)
dist_coords = ((places_coords - airport_coords)**2).sum(axis=-1)
min_dist = dist_coords.min(axis=1)

airport_distance['airport_dist_large'] = min_dist
airport_distance.head()
# Out:
#                  location  airport_dist_any  airport_dist_large
# 0  Argentina-Buenos_Aires          0.003183            0.071514
# 1          Argentina-CABA          0.003183            0.071514
# 2       Argentina-Cordoba          0.009602           43.526915
# 3    Argentina-Entre_Rios          0.000658           13.126461
# 4      Argentina-Santa_Fe          0.023428           14.983910

# %%
save_it(airport_distance, '11_feature_engineering_airport_distance')

# %%
with open('./pkl/04_weekly_weather.pkl', 'rb') as fh:
    weather = dill.load(fh)

weather.head(2)
# Out:
#         date  max_temp  max_temp1  max_temp2         location  mean_temp  \
# 0 2015-11-28      94.0       94.0       94.0  Mexico-Guerrero       84.0
# 1 2015-12-05      93.0       94.0       94.0  Mexico-Guerrero       82.0
#
#    mean_temp1  mean_temp2  min_temp  min_temp1  min_temp2  dew_point  \
# 0        84.0        84.0      73.0       75.0       74.0       75.0
# 1        84.0        84.0      72.0       73.0       75.0       74.0
#
#    dew_point1  dew_point2  precipitation  precipitation1  precipitation2  \
# 0        78.0        77.0           1.22            0.00             0.0
# 1        75.0        78.0           0.00            1.22             0.0
#
#    wind  wind1  wind2
# 0   4.0    4.0    4.0
# 1   4.0    4.0    4.0

# %%
save_it(weather, '11_feature_engineering_weather')

# %%
with open('./pkl/05_mosquito_sightings.pkl', 'rb') as fh:
    mosquito = dill.load(fh)
mosquito.head(1)
# Out:
#                  vector  occurrence_id  source_type location_type  \
# 34478  Aedes albopictus          34479  unpublished         point
#
#       polygon_admin  latitude  longitude  year country country_id  gaul_ad0  \
# 34478          -999     22.89     120.44  2006  Taiwan        TWN       886
#
#       status
# 34478    NaN

# %%
with open('./pkl/06_population_density.pkl', 'rb') as fh:
    population = dill.load(fh)
population.head(1)
# Out:
#                  location  density_per_km
# 0  Argentina-Buenos_Aires    12625.800781

# %%
save_it(population, '11_feature_engineering_population')
